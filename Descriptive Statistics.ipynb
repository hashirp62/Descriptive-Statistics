# %% [markdown]
# #Descriptive Statistics
#
# 1. Understanding Central Tendency
#
#    Calculate the median A bakery tracks the daily sales of muffins (in dozens) over a weeek [10, 12, 11, 15, 14, 13, 12].
#
#    What is the most representative value of their weekly sales, and why?
#
#  >  To find the most representative value of the sales we could use three basic method of statistics ** MEAD MEDIAN AND MODE**
#
#
#    Sales data (in dozens):
#    10, 12, 11, 15, 14, 13, 12
#
#    MEAN=
#
#   10+12+11+15+14+13+12/7
#
#   = 87/7
#
#   = 12.43
#
#   MEDIAN:
#
#   Arrange the sales data in order first
#
#   10,11,12,12,13,14,15
#
#   median is the value in centre of the dataset basically
#
#    thus median= **12**
#
#   MODE:
#
#   this  is most frequent value in the dataset
#
#   that will **12**
#
#   Most representative value is **12**. both median and mode is resulting 12 and mean is closest to 12 also. This method is also called **CENTRAL TENDENCY**
#
# 2. Mean in Real Life
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class's performance?
#
#   > Score of each student is
#
#   12, 15, 14, 16, 18, 20, 19
#
#   mean= 12+15+14+16+18+20+19/7
#
#   = 114/7
#
#   = 16.28
#
#   **16.28 is the mean of the score**. this represents that the average score of the students in the quiz will be 16 marks
#
# 3. Mode in Real Life
#
#    A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9]. What is the mode, and why is this information useful for the store manager?
#
#  > Shoe size sold: 7, 8, 9, 8, 8, 10, 7, 9
#
#   as we know mode is the most repeated value in the data. so here
#
#   7 > 2 times
#
#   8 > 3 times
#
#   9 > 2 times
#
#   10 > 1 time
#
#   **8 is the most repeated value here therefore mode is 8**
#
#   this helps the shopkeeper to understand the most demanded size. so he can store that particular size(8) more quantity.
#
# 4. Median in Real Life
#
#    A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
#
#    Why is the median a better measure than the mean in this case? Calculate the median?
#
#  > To find the median we have to arrange the data in ascending order first to get the better output
#
#   8,000, 9,500, 10,200, 11,000, 50,000
#
#   here median= **$10,200**
#
#  **In this scenario it is better to take median because $50,000 is an outlier which will effect the average** showcasing a negative analysis.
#
# 5. Dispersion Introduction
#
#    A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
#
#    What does the range tell us about the variation in the student's puzzle-solving time?
#
#  > To find the range of 25, 30, 27, 35, 40
#
#    = highest value - lowest value
#
#    = 40-25
#
#    = 15
#
#    the range is **15 minutes**
#
#    from this we can understand we can understand that the students puzzle solving time varies by 15 minutes from shortest to longest time.
#
#    this a variation in the time is noticeble range and there is huge variation each time. this show somedays the student is fast and somedays the student is slow
#
# 6. Range in Action
#
#    A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].Find the range. How can this help the farmer in planning his packaging?
#
#  > weekly weight of the apple=
#
#    100, 105, 98, 110, 120
#
#    range= highest value-lowest value
#
#    = 120-98
#
#    = 22
#
#    so, range of the havested apple is 22kg
#
#    this helps the farmer to decide the size and quantity of the packaging material or boxes
#
#    helps in preventing shortage of packing supplies
#
#    helps in planning of storage and transportation
#
#    other than that he can also understand the variation in weekly production. helps him in decision making for a consistent and better harvesting.
#
# 7. Variance for Decision-Making
#
#    Two delivery companies track delivery delays (in minutes).
#
#    - Company A: variance = 6
#
#    - Company B: variance = 15
#
#    Which company is more consistent, and why?
#
#  >  **compaany A is more consistent than company B. because is has only a variation of 6 minutes compared to the company B.** the variation of the time of company B is more than 100% from company A. therefore it will lead to higher fluctuation and least predictable.
#
#  Meanwhile **a smaller variance means the delays are closer to the mean**. thus company A has stable and reliable performence so they can be more trusted.
#
# 8. Standard Deviation in Context
#
#    A finance student compares the daily price fluctuations of two cryptocurrencies.
#
#    Coin A: standard deviation = $30
#
#    Coin B: standard deviation = $120
#
#    Which coin is riskier to invest in, and why?
#
#  > **Investing in coin B is riskier compared to investing in coin A**
#
#    In this scenario standard deviation measures the fluctaiton of price from the average price
#
#    thus coin B has fluctuation of 120 compared to coin B that is 30 from the average
#
#    also there is no base or average price mentioned in this scenario. so we can only analyse by looking at the higher flactuting amount
#
#    from this we can assume that coin A has only 30 dollar flactuating showcasing that small range of difference making it more stable but coin B has dollor 120 flactition making it a riskier and volatile coin to invest.
#
# 9. Combining Measures
#
#    A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
#
#    Find the mean and standard deviation. What do these values together tell you about the family's energy use
#    pattern?
#
#  > Mean=
#
#    400+420+390+450+410/5
#
#    = 2070/5
#
#    = 414
#
#    Mean= **414kwh**
#
#    Standard deviation=
#
#    varience=
#
#    400-414 = -14
#
#    420-414 = 6
#
#    390-414 = -24
#
#    450-414 = 36
#
#    410-414 = -4
#
#    now square the variance, the entire squared value and divide it by number of values.
#
#    = 196+36+576+1296+16/5
#
#    = 2120/5
#
#    = 424
#
#    Now square root the value(424)
#
#    = 20.59
#
#    the standard deviation of the usage in electricity will **20.59kwh**
#
#    **Mean= 414kwh**
#
#    **standard deviation= 20.59kwh**
#
#    From this we can understand that the family electricity usage is almost constant with no major variance betweeen usage in 5 months
#
# 10. Practical Application
#
#   A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
#
#   Find the mean, median, mode, range, and standard deviation. What insights can these measures provide about the player's scoring performance?
#
#  > first lets make this data into ascending order for a better smooth process
#
#    15,17,18,19,20,21,22,25
#
#    Mean= 15+17+18+19+20+21+22+25/8
#
#    = 157/8
#
#    = 19.625  = 19.63
#
#    Mean= **19.63**
#
#    Median:
#
#    since there are even numbers of data we have to take take middle two middle data and divide it by 2
#
#    =19+20/2
#
#    =39/2
#
#    =19.5
#
#    So, **median is 19.5**
#
#    Mode=
#
#    **since there are no same multiple entires there's no mode**
#
#    Range=
#
#    **minumum value - maximum value**
#
#    that is **15-25 = 10**
#
#    **Range= 10**
#
#    Standard deviation
#
#    variance from the mean
#
#    15-19.625 = -4.625
#
#    17-19.625 = -2.625
#
#    18-19.625 = -1.625
#
#    19-19.625 = -0.625
#
#    20-19.625 = 0.375
#
#    21-19.625 = 1.375
#
#    22-19.625 = 2.375
#
#    25-19.625 = 5.375
#
#    now square all the variance and add it
#
#    = 21.3906+6.8906+2.6406+0.3906+0.1406+1.8906+5.6406+28.8906
#
#
#    = 67.8748
#
#    rounding to 67.875
#
#    Now divide this value by 8-1
#
#    = 67.875/8-1
#
#    = 67.875/7
#
#    = 9.696
#
#    now square root this value to get the standard deviation that is
#
#    standard deviation= 3.1138
#
#    rounding to **3.11**
#
#    So the **sample standard deviation will be 3.11**
#
#    **Mean= 19.63**
#
#    **median is 19.5**
#
#    **since there are no same multiple entires there's no mode**
#
#    **Range= 10**
#
#    **sample standard deviation= 3.11**
